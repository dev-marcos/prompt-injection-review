# %% [markdown]
# # Análise consolidada — Prompt Injection Review
#
# Este notebook consolida os resultados de triagem por título/resumo provenientes de **IEEE** e **Springer**, valida as avaliações produzidas pelo `SCREENING_PROTOCOL_v1.0`, identifica pendências e duplicatas, calcula estatísticas descritivas e gera arquivos para a futura fase de leitura integral dos PDFs.
#
# > Execute este notebook a partir da pasta `NEW`, isto é, a pasta que contém `IEEE/` e `Springer/`.

# %%
from pathlib import Path
import json
import re
import unicodedata

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 120)

ROOT = Path.cwd()

IEEE_DIR = ROOT / "IEEE" / "IEEE-S1"
IEEE_RESULTS_DIR = IEEE_DIR / "IEEE_S1_batches_20" / "results"

SPRINGER_DIR = ROOT / "Springer"
SPRINGER_BATCH_DIR = SPRINGER_DIR / "SPRINGER_S1_batches_20"
SPRINGER_RESULTS_DIR = SPRINGER_BATCH_DIR / "results"

OUTPUT_DIR = ROOT / "analysis_outputs"
OUTPUT_DIR.mkdir(exist_ok=True)

print("ROOT:", ROOT)
print("IEEE existe:", IEEE_DIR.exists())
print("Springer existe:", SPRINGER_DIR.exists())
# Out:
# ROOT: c:\Users\Marcos Rocha\Downloads\prompt-injection-review\NEW
# IEEE existe: True
# Springer existe: True

# %% [markdown]
# ## Configuração provisória para explorar a seleção
#
# A rubrica não muda. O ponto de corte abaixo serve apenas para observar quantos estudos seriam encaminhados ao texto completo.

# %%
FULL_TEXT_THRESHOLD = 0.85
LOW_CONFIDENCE_THRESHOLD = 0.60
GRAY_ZONE_MARGIN = 0.05

# %% [markdown]
# ## Funções auxiliares

# %%
def clean_text(value):
    if value is None:
        return ""
    return re.sub(r"\s+", " ", str(value)).strip()


def normalize_title(value):
    value = clean_text(value)
    value = value.replace(r"\{", "").replace(r"\}", "")
    value = value.replace("{", "").replace("}", "")
    value = value.replace("\\", "")
    value = unicodedata.normalize("NFKD", value)
    value = "".join(ch for ch in value if not unicodedata.combining(ch))
    value = value.lower()
    value = re.sub(r"[^a-z0-9]+", " ", value)
    return re.sub(r"\s+", " ", value).strip()


def normalize_doi(value):
    value = clean_text(value).lower()
    value = re.sub(r"^https?://(?:dx\.)?doi\.org/", "", value)
    value = re.sub(r"^doi:\s*", "", value)
    return value.strip()


def split_bibtex_entries(text):
    entries = []
    pos = 0
    n = len(text)

    while pos < n:
        at = text.find("@", pos)
        if at == -1:
            break

        brace = text.find("{", at)
        if brace == -1:
            break

        depth = 0
        i = brace

        while i < n:
            if text[i] == "{":
                depth += 1
            elif text[i] == "}":
                depth -= 1
                if depth == 0:
                    entries.append(text[at:i+1])
                    pos = i + 1
                    break
            i += 1
        else:
            raise ValueError(f"Entrada BibTeX não fechada a partir da posição {at}")

    return entries


def parse_bib_entry(raw):
    head = re.match(r"@([A-Za-z]+)\{([^,]+),", raw, flags=re.S)
    if not head:
        return {}

    entry_type = head.group(1).lower()
    citation_key = head.group(2).strip()
    pos = head.end()

    out = {"bib_key": citation_key, "entry_type": entry_type}

    while pos < len(raw):
        while pos < len(raw) and raw[pos] in " \t\r\n,":
            pos += 1

        if pos >= len(raw) or raw[pos] == "}":
            break

        match = re.match(r"([A-Za-z][A-Za-z0-9_-]*)\s*=\s*", raw[pos:])
        if not match:
            pos += 1
            continue

        field = match.group(1).lower()
        pos += match.end()

        if pos >= len(raw):
            break

        if raw[pos] == "{":
            depth = 1
            start = pos + 1
            pos += 1
            while pos < len(raw) and depth:
                if raw[pos] == "{":
                    depth += 1
                elif raw[pos] == "}":
                    depth -= 1
                pos += 1
            value = raw[start:pos-1]

        elif raw[pos] == '"':
            pos += 1
            start = pos
            while pos < len(raw):
                if raw[pos] == '"' and raw[pos-1] != "\\":
                    value = raw[start:pos]
                    pos += 1
                    break
                pos += 1
        else:
            start = pos
            while pos < len(raw) and raw[pos] not in ",}":
                pos += 1
            value = raw[start:pos]

        out[field] = clean_text(value)

    return out


def bib_files_to_dataframe(files, database):
    records = []

    for path in files:
        text = path.read_text(encoding="utf-8-sig", errors="replace")
        entries = split_bibtex_entries(text)

        for entry in entries:
            data = parse_bib_entry(entry)
            if not data:
                continue

            records.append({
                "database": database,
                "source_file": path.name,
                "bib_key": data.get("bib_key", ""),
                "entry_type": data.get("entry_type", ""),
                "title": data.get("title", ""),
                "abstract": data.get("abstract", ""),
                "authors": data.get("author", ""),
                "year": data.get("year", ""),
                "doi": normalize_doi(data.get("doi", "")),
                "url": data.get("url", ""),
                "venue": (
                    data.get("journal", "")
                    or data.get("booktitle", "")
                    or data.get("publisher", "")
                ),
                "content_type": data.get("type", ""),
            })

    df = pd.DataFrame(records)

    if not df.empty:
        df["title_norm"] = df["title"].map(normalize_title)

    return df


def read_jsonl_results(results_dir, database):
    rows = []

    if not results_dir.exists():
        print(
            f"[INFO] Pasta de resultados ainda não existe: "
            f"{results_dir}"
        )
        return pd.DataFrame()

    files = sorted(results_dir.glob("*.jsonl"))

    print(
        f"{database}: "
        f"{len(files)} arquivo(s) JSONL encontrado(s)"
    )

    for path in files:
        with path.open(
            "r",
            encoding="utf-8-sig"
        ) as f:

            for line_no, line in enumerate(f, start=1):

                line = line.strip()

                if not line:
                    continue

                try:
                    obj = json.loads(line)

                except json.JSONDecodeError as exc:

                    inicio = max(
                        0,
                        exc.pos - 150
                    )

                    fim = min(
                        len(line),
                        exc.pos + 150
                    )

                    trecho = line[inicio:fim]

                    raise ValueError(
                        "\n\nJSONL INVÁLIDO\n"
                        f"Base: {database}\n"
                        f"Arquivo: {path}\n"
                        f"Linha: {line_no}\n"
                        f"Coluna: {exc.colno}\n"
                        f"Erro: {exc.msg}\n\n"
                        f"Trecho:\n{trecho}\n\n"
                        "Corrija essa linha antes de continuar."
                    ) from exc

                scores = obj.get(
                    "scores",
                    {}
                ) or {}

                rows.append({
                    "database": database,

                    "evaluation_file":
                        path.name,

                    "screening_id":
                        obj.get("id", ""),

                    "title":
                        obj.get("title", ""),

                    "title_norm":
                        normalize_title(
                            obj.get("title", "")
                        ),

                    "relevance_score":
                        obj.get(
                            "relevance_score"
                        ),

                    "confidence":
                        obj.get(
                            "confidence"
                        ),

                    "phenomenon_centrality":
                        scores.get(
                            "phenomenon_centrality"
                        ),

                    "rq_contribution":
                        scores.get(
                            "rq_contribution"
                        ),

                    "application_context":
                        scores.get(
                            "application_context"
                        ),

                    "evidence_or_synthesis":
                        scores.get(
                            "evidence_or_synthesis"
                        ),

                    "information_density":
                        scores.get(
                            "information_density"
                        ),

                    "hard_exclude":
                        obj.get(
                            "hard_exclude",
                            False
                        ),

                    "study_type":
                        obj.get(
                            "study_type",
                            ""
                        ),

                    "contribution_types":
                        obj.get(
                            "contribution_types",
                            []
                        ) or [],

                    "contexts":
                        obj.get(
                            "contexts",
                            []
                        ) or [],

                    "possible_duplicate_llm":
                        obj.get(
                            "possible_duplicate",
                            False
                        ),

                    "reason":
                        obj.get(
                            "reason",
                            ""
                        ),
                })

    return pd.DataFrame(rows)


def validate_screening_scores(df):
    if df.empty:
        return df.copy()

    out = df.copy()

    cols = [
        "phenomenon_centrality",
        "rq_contribution",
        "application_context",
        "evidence_or_synthesis",
        "information_density",
        "relevance_score",
        "confidence",
    ]

    for col in cols:
        out[col] = pd.to_numeric(out[col], errors="coerce")

    out["score_recalculated"] = (
        0.35 * out["phenomenon_centrality"]
        + 0.25 * out["rq_contribution"]
        + 0.15 * out["application_context"]
        + 0.15 * out["evidence_or_synthesis"]
        + 0.10 * out["information_density"]
    ).round(2)

    out.loc[out["hard_exclude"] == True, "score_recalculated"] = 0.00

    out["score_difference"] = (
        out["relevance_score"] - out["score_recalculated"]
    ).abs().round(4)

    out["score_formula_ok"] = out["score_difference"].fillna(999) <= 0.01

    return out


def merge_metadata_screening(metadata, screening):
    metadata = metadata.copy()

    if screening.empty:
        metadata["screening_status"] = "PENDING"
        return metadata

    merged = metadata.merge(
        screening.drop(columns=["database", "title"], errors="ignore"),
        on="title_norm",
        how="left",
    )

    merged["screening_status"] = merged["relevance_score"].notna().map(
        {True: "EVALUATED", False: "PENDING"}
    )
    return merged


def add_priority_band(df):
    out = df.copy()

    def band(score):
        if pd.isna(score):
            return "PENDING"
        if score >= 0.80:
            return "0.80–1.00 alta prioridade"
        if score >= 0.65:
            return "0.65–0.79 provável relevância"
        if score >= 0.50:
            return "0.50–0.64 zona cinzenta"
        if score >= 0.25:
            return "0.25–0.49 baixa prioridade"
        return "0.00–0.24 provável exclusão"

    out["priority_band"] = out["relevance_score"].map(band)
    return out


def make_dedup_key(row):
    doi = normalize_doi(row.get("doi", ""))
    if doi:
        return "doi:" + doi
    return "title:" + normalize_title(row.get("title", ""))


def explode_counts(df, column):
    if df.empty or column not in df:
        return pd.Series(dtype=int)

    values = df[column].explode().dropna().astype(str)
    values = values[values.str.len() > 0]
    return values.value_counts()


def first_nonempty(series):
    for value in series:
        if isinstance(value, list):
            if value:
                return value
        elif pd.notna(value) and str(value).strip():
            return value
    return ""

# %% [markdown]
# ## Carregar os BibTeX

# %%
# IEEE: apenas os cinco arquivos originais da exportação.
ieee_master_pattern = re.compile(r"^IEEE_S1_\d{3}-\d{3}\.bib$", re.I)

ieee_bib_files = sorted(
    p for p in IEEE_DIR.glob("*.bib")
    if ieee_master_pattern.match(p.name)
)

# Springer: o BibTeX foi produzido diretamente em batches.
springer_bib_files = sorted(
    SPRINGER_BATCH_DIR.glob("SPRINGER_S1_batch_*.bib")
)

ieee_meta = bib_files_to_dataframe(ieee_bib_files, "IEEE")
springer_meta = bib_files_to_dataframe(springer_bib_files, "Springer")

print("IEEE arquivos:", len(ieee_bib_files), "| registros:", len(ieee_meta))
print("Springer arquivos:", len(springer_bib_files), "| registros:", len(springer_meta))
# Out:
# IEEE arquivos: 5 | registros: 464
# Springer arquivos: 5 | registros: 91

# %% [markdown]
# ## Ler e validar os JSONL já produzidos

# %%
from pathlib import Path
import json

def validar_jsonl_pasta(pasta):
    erros = []
    total_linhas = 0
    total_validas = 0

    arquivos = sorted(Path(pasta).glob("*.jsonl"))

    print(f"Arquivos encontrados: {len(arquivos)}\n")

    for arquivo in arquivos:
        validas_arquivo = 0
        erros_arquivo = 0

        with arquivo.open("r", encoding="utf-8-sig") as f:
            for numero_linha, linha in enumerate(f, start=1):
                linha = linha.strip()

                if not linha:
                    continue

                total_linhas += 1

                try:
                    json.loads(linha)
                    total_validas += 1
                    validas_arquivo += 1

                except json.JSONDecodeError as exc:
                    erros_arquivo += 1

                    inicio = max(0, exc.pos - 120)
                    fim = min(len(linha), exc.pos + 120)

                    trecho = linha[inicio:fim]

                    erros.append({
                        "arquivo": arquivo,
                        "linha": numero_linha,
                        "erro": exc.msg,
                        "coluna": exc.colno,
                        "posicao": exc.pos,
                        "trecho": trecho,
                        "conteudo_completo": linha,
                    })

                    print("=" * 80)
                    print(f"ERRO: {arquivo.name}")
                    print(f"Linha: {numero_linha}")
                    print(f"Coluna: {exc.colno}")
                    print(f"Mensagem: {exc.msg}")
                    print()
                    print("Trecho ao redor do erro:")
                    print(trecho)
                    print()
                    print(" " * min(120, exc.pos - inicio) + "^")
                    print("=" * 80)
                    print()

        print(
            f"{arquivo.name}: "
            f"{validas_arquivo} válidas, "
            f"{erros_arquivo} inválidas"
        )

    print("\nRESUMO")
    print("-" * 40)
    print("Linhas com conteúdo:", total_linhas)
    print("JSON válidos:", total_validas)
    print("JSON inválidos:", len(erros))

    return erros


erros_ieee = validar_jsonl_pasta(IEEE_RESULTS_DIR)
# Out:
# Arquivos encontrados: 24
#
# IEEE_S1_batch_001-020.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_021-040.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_041-060.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_061-080.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_081-100.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_101-120.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_121-140.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_141-160.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_161-180.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_181-200.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_201-220.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_221-240.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_241-260.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_261-280.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_281-300.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_301-320.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_321-340.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_341-360.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_361-380.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_381-400.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_401-420.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_421-440.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_441-460.jsonl: 20 válidas, 0 inválidas
# IEEE_S1_batch_461-464.jsonl: 4 válidas, 0 inválidas
#
# RESUMO
# ----------------------------------------
# Linhas com conteúdo: 464
# JSON válidos: 464
# JSON inválidos: 0

# %%
ieee_screen = validate_screening_scores(
    read_jsonl_results(IEEE_RESULTS_DIR, "IEEE")
)

springer_screen = validate_screening_scores(
    read_jsonl_results(SPRINGER_RESULTS_DIR, "Springer")
)

print("IEEE avaliações encontradas:", len(ieee_screen))
print("Springer avaliações encontradas:", len(springer_screen))

validation = pd.concat(
    [
        x for x in [ieee_screen, springer_screen]
        if not x.empty
    ],
    ignore_index=True,
) if (not ieee_screen.empty or not springer_screen.empty) else pd.DataFrame()

invalid_scores = (
    validation.loc[~validation["score_formula_ok"]].copy()
    if not validation.empty
    else pd.DataFrame()
)

print("Avaliações com divergência da fórmula:", len(invalid_scores))

if len(invalid_scores):
    display(
        invalid_scores[
            [
                "database",
                "evaluation_file",
                "title",
                "relevance_score",
                "score_recalculated",
                "score_difference",
            ]
        ]
    )
# Out:
# IEEE: 24 arquivo(s) JSONL encontrado(s)
# [INFO] Pasta de resultados ainda não existe: c:\Users\Marcos Rocha\Downloads\prompt-injection-review\NEW\Springer\SPRINGER_S1_batches_20\results
# IEEE avaliações encontradas: 464
# Springer avaliações encontradas: 0
# Avaliações com divergência da fórmula: 0

# %% [markdown]
# ## Consolidar metadados + avaliações

# %%
ieee = merge_metadata_screening(ieee_meta, ieee_screen)
springer = merge_metadata_screening(springer_meta, springer_screen)

combined = pd.concat([ieee, springer], ignore_index=True, sort=False)
combined = add_priority_band(combined)
combined["dedup_key"] = combined.apply(make_dedup_key, axis=1)

summary_status = (
    combined.groupby(["database", "screening_status"])
    .size()
    .unstack(fill_value=0)
)

summary_status["TOTAL"] = summary_status.sum(axis=1)
display(summary_status)

print("Total:", len(combined))
print("Avaliados:", (combined["screening_status"] == "EVALUATED").sum())
print("Pendentes:", (combined["screening_status"] == "PENDING").sum())
# Out:
# screening_status  EVALUATED  PENDING  TOTAL
# database
# IEEE                    462        4    466
# Springer                  0       91     91
# Total: 557
# Avaliados: 462
# Pendentes: 95

# %% [markdown]
# ## Verificar JSONL que não casaram com os BibTeX

# %%
def unmatched_screening(metadata, screening):
    if screening.empty:
        return pd.DataFrame()

    titles = set(metadata["title_norm"])
    return screening.loc[~screening["title_norm"].isin(titles)].copy()


unmatched_ieee = unmatched_screening(ieee_meta, ieee_screen)
unmatched_springer = unmatched_screening(springer_meta, springer_screen)

print("IEEE sem correspondência:", len(unmatched_ieee))
print("Springer sem correspondência:", len(unmatched_springer))

if len(unmatched_ieee):
    display(unmatched_ieee[["evaluation_file", "title", "screening_id"]])

if len(unmatched_springer):
    display(unmatched_springer[["evaluation_file", "title", "screening_id"]])
# Out:
# IEEE sem correspondência: 4
# Springer sem correspondência: 0
#                  evaluation_file  \
# 69   IEEE_S1_batch_061-080.jsonl
# 322  IEEE_S1_batch_321-340.jsonl
# 442  IEEE_S1_batch_441-460.jsonl
# 445  IEEE_S1_batch_441-460.jsonl
#
#                                                                                                                        title  \
# 69                                    AI Under Attack: A Practical Guide to Threats, Defenses, and Governance for AI Systems
# 322  Context Engineering for Multi-Agent Systems: Move beyond prompting to build a Context Engine, a transparent architec...
# 442  Adversarial AI Attacks, Mitigations, and Defense Strategies: A cybersecurity professional's guide to AI attacks, thr...
# 445                                                                                                  Generative AI in Action
#
#     screening_id
# 69      11600789
# 322     11297083
# 442     10769346
# 445     10745288

# %% [markdown]
# ## Detectar duplicatas por DOI ou título

# %%
dup_mask = combined.duplicated("dedup_key", keep=False)

duplicates = (
    combined.loc[dup_mask]
    .sort_values(["dedup_key", "database", "title"])
    .copy()
)

print("Registros em grupos duplicados:", len(duplicates))
print("Grupos duplicados:", duplicates["dedup_key"].nunique())

if len(duplicates):
    display(
        duplicates[
            [
                "database",
                "title",
                "doi",
                "year",
                "screening_status",
                "relevance_score",
                "dedup_key",
            ]
        ]
    )
# Out:
# Registros em grupos duplicados: 4
# Grupos duplicados: 1
#     database title doi  year screening_status  relevance_score dedup_key
# 69      IEEE            2026          PENDING              NaN    title:
# 322     IEEE            2025          PENDING              NaN    title:
# 442     IEEE            2024          PENDING              NaN    title:
# 445     IEEE            2024          PENDING              NaN    title:

# %% [markdown]
# ## Criar dataset em nível de estudo único

# %%
study_rows = []

for key, group in combined.groupby("dedup_key", dropna=False):
    evaluated = group.loc[group["screening_status"] == "EVALUATED"].copy()
    scores = pd.to_numeric(evaluated["relevance_score"], errors="coerce").dropna()

    score = scores.median() if len(scores) else None
    score_range = scores.max() - scores.min() if len(scores) > 1 else 0.0

    study_rows.append({
        "study_key": key,
        "sources": sorted(group["database"].dropna().unique().tolist()),
        "source_count": group["database"].nunique(),
        "title": first_nonempty(group["title"]),
        "abstract": first_nonempty(group["abstract"]),
        "authors": first_nonempty(group["authors"]),
        "year": first_nonempty(group["year"]),
        "doi": first_nonempty(group["doi"]),
        "url": first_nonempty(group["url"]),
        "venue": first_nonempty(group["venue"]),
        "screening_status": "EVALUATED" if len(evaluated) else "PENDING",
        "n_evaluations": len(evaluated),
        "relevance_score": score,
        "score_range_if_repeated": round(float(score_range), 4) if len(scores) else None,
        "confidence": (
            pd.to_numeric(evaluated["confidence"], errors="coerce").median()
            if len(evaluated) else None
        ),
        "hard_exclude": (
            bool(evaluated["hard_exclude"].fillna(False).all())
            if len(evaluated) else False
        ),
        "study_type": first_nonempty(evaluated["study_type"]) if len(evaluated) else "",
        "contribution_types": sorted({
            item
            for values in evaluated["contribution_types"]
            if isinstance(values, list)
            for item in values
        }),
        "contexts": sorted({
            item
            for values in evaluated["contexts"]
            if isinstance(values, list)
            for item in values
        }),
        "reason": first_nonempty(evaluated["reason"]) if len(evaluated) else "",
    })

studies = pd.DataFrame(study_rows)
studies = add_priority_band(studies)

print("Registros brutos:", len(combined))
print("Estudos únicos:", len(studies))
print("Duplicatas consolidadas:", len(combined) - len(studies))
# Out:
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# ...
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())
# C:\Users\Marcos Rocha\AppData\Local\Temp\ipykernel_24384\2356231957.py:30: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bool(evaluated["hard_exclude"].fillna(False).all())

# %% [markdown]
# ## Insights do screening

# %%
evaluated_studies = studies.loc[
    studies["screening_status"] == "EVALUATED"
].copy()

print("Estudos únicos avaliados:", len(evaluated_studies))

if len(evaluated_studies):
    display(
        evaluated_studies["relevance_score"]
        .describe(percentiles=[0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
        .to_frame("relevance_score")
    )

    fig, ax = plt.subplots(figsize=(9, 5))
    ax.hist(
        evaluated_studies["relevance_score"].dropna(),
        bins=[i / 20 for i in range(21)],
        edgecolor="black",
    )
    ax.set_title("Distribuição dos relevance_score")
    ax.set_xlabel("relevance_score")
    ax.set_ylabel("Número de estudos")
    plt.show()

    print("Tipos de estudo:")
    display(
        evaluated_studies["study_type"]
        .replace("", "UNCLASSIFIED")
        .value_counts()
        .to_frame("n")
    )

    print("Contextos:")
    display(explode_counts(combined.loc[combined["screening_status"]=="EVALUATED"], "contexts").to_frame("n"))

    print("Contribuições:")
    display(explode_counts(combined.loc[combined["screening_status"]=="EVALUATED"], "contribution_types").to_frame("n"))
# Out:
# Estudos únicos avaliados: 362
#        relevance_score
# count       362.000000
# mean          0.796409
# std           0.208289
# min           0.000000
# 10%           0.512000
# 25%           0.690000
# 50%           0.890000
# 75%           0.930000
# 90%           0.960000
# 95%           0.960000
# max           0.990000
# Tipos de estudo:
#                              n
# study_type
# PRIMARY_DEFENSE             72
# PRIMARY_ATTACK              67
# DETECTION                   52
# APPLICATION_SECURITY        47
# BENCHMARK_EVALUATION        43
# PRIMARY_ATTACK_AND_DEFENSE  18
# RED_TEAMING                 17
# OTHER                       16
# SURVEY                      16
# REVIEW                       8
# TAXONOMY                     6
# Contextos:
#                           n
# contexts
# GENERAL_LLM             332
# CYBERSECURITY           149
# UNTRUSTED_INPUT          59
# AGENT                    54
# EXTERNAL_CONTENT         50
# MULTIMODAL               47
# CHATBOT                  45
# OTHER                    40
# RAG                      27
# MULTI_AGENT              20
# DOCUMENT_PROCESSING       9
# WEB                       9
# EMAIL                     4
# INFORMATION_EXTRACTION    4
# HTML                      3
# DOCUMENT_UNDERSTANDING    2
# Contribuições:
#                       n
# contribution_types
# EVALUATION          304
# DEFENSE             158
# FRAMEWORK           139
# ATTACK              137
# MITIGATION          129
# DETECTION           108
# BENCHMARK            46
# PREVENTION           44
# RED_TEAMING          36
# DATASET              32
# TAXONOMY             24
# SURVEY               19
# REVIEW               15
# OTHER                 8
# FORENSICS             4

# %% [markdown]
# ## Simular candidatos para leitura integral

# %%
full_text_candidates = (
    evaluated_studies.loc[
        (evaluated_studies["hard_exclude"] == False)
        & (evaluated_studies["relevance_score"] >= FULL_TEXT_THRESHOLD)
    ]
    .sort_values(["relevance_score", "confidence"], ascending=[False, False])
    .copy()
)

gray_zone = (
    evaluated_studies.loc[
        (evaluated_studies["hard_exclude"] == False)
        & (
            evaluated_studies["relevance_score"].between(
                FULL_TEXT_THRESHOLD - GRAY_ZONE_MARGIN,
                FULL_TEXT_THRESHOLD + GRAY_ZONE_MARGIN,
                inclusive="both",
            )
            | (evaluated_studies["confidence"].fillna(0) < LOW_CONFIDENCE_THRESHOLD)
        )
    ]
    .sort_values(["relevance_score", "confidence"], ascending=[False, True])
    .copy()
)

print(
    f"Candidatos provisórios (score >= {FULL_TEXT_THRESHOLD:.2f}):",
    len(full_text_candidates),
)
print("Zona de revisão manual:", len(gray_zone))

display(
    full_text_candidates[
        [
            "title",
            "sources",
            "year",
            "doi",
            "relevance_score",
            "confidence",
            "study_type",
            "contexts",
            "contribution_types",
            "reason",
        ]
    ].head(50)
)
# Out:
# Candidatos provisórios (score >= 0.80): 243
# Zona de revisão manual: 39
#                                                                                                                        title  \
# 119         TrustTrace: Provenance-Aware Tracing of Indirect Prompt Injection Propagation in LLM-Assisted Learning Workflows
# 292                                                     DarkCite: Unveiling Authority Bias as Implicit Rag Jailbreak Attacks
# 342                         Visual and Structural Prompt Injection in Medical Rag Systems: a Comparative Robustness Analysis
# 445                             Disrupting Large Language Models with Hidden Prompt Injection Attacks Embedded in HTML Pages
# 456                                                             Get My Drift? Catching LLM Task Drift with Activation Deltas
# 259                                      Zero-Shot Tokenizer Transfer for Targeted Attacks on Retrieval-Augmented Generation
# 90                                     Hold the Prompt (HODPOT): Defense Design for Securing the System Prompt of LLM Agents
# 112                                     A Systematic Literature Review of Prompt Injection Attacks in LLM-Integrated Systems
# 139                                     Automatically Generated Multi-Agent Framework for Jailbreaking Large Language Models
# 157                          Securing Vision-Language Models with a Robust Encoder Against Jailbreak and Adversarial Attacks
# 208                                             Distraction is All You Need for Multimodal Large Language Model Jailbreaking
# 209                             Immune: Improving Safety Against Jailbreaks in Multi-modal LLMs via Inference-Time Alignment
# 210                                Playing the Fool: Jailbreaking LLMs and Multimodal LLMs with Out-of-Distribution Strategy
# 220                                  Audio Jailbreak Attacks: Exposing Vulnerabilities in SpeechGPT in a White-Box Framework
# 239               Image-based Prompt Injection: Hijacking Multimodal LLMs through Visually Embedded Adversarial Instructions
# 281                             ATTN-Defense: Attention-Guided Detection, Location and Removal for Indirect Prompt Injection
# 285                                                                  PINA: Prompt Injection Attack Against Navigation Agents
# 291                  IPI2: Mitigating Indirect Prompt Injections on Unmanned Aerial Vehicle Agents Using Physical Invariants
# 295                                       CAS-J: Cross-Modal Attention Synergy for Jailbreaking Large Vision-Language Models
# 296                          Audio-Text Jailbreak Attack on Large Audio-Language Models: Towards Generality and Stealthiness
# 307                  Code Poisoning Through Misleading Comments: Jailbreaking Large Language Models via Contextual Deception
# 317                                                  Jailbreaking Multimodal Large Language Models via Shuffle Inconsistency
# 318                     Heuristic-Induced Multimodal Risk Distribution Jailbreak Attack for Multimodal Large Language Models
# 320                                     Ideator: Jailbreaking and Benchmarking Large Vision-Language Models Using Themselves
# 324               Securing Autonomous Clinical Agents: Time-Scoped Hypergraph Delegation for Controlling Patient Data Access
# 352                                                FlowJD: Your Imagination Can Help You Jailbreak in Visual Language Models
# 353                                 PiCo: Jailbreaking Multimodal Large Language Models via Pictorial Code Contextualization
# 363                         The Dark Side of AI: a Systematization of Knowledge on Jailbreaking and Prompt Injection in LLMs
# 364                                                                                       Jailbreaking LLM-Controlled Robots
# 394                                 DEO: Jailbreak a Black-box Multimodal Large Language Model with Dual-Embedding Alignment
# 396                                  Whispers of Wealth: A Systematic Red-Teaming Study of the Agent Payments Protocol (AP2)
# 477  Fun-tuning: Characterizing the Vulnerability of Proprietary LLMs to Optimization-Based Prompt Injection Attacks via ...
# 478                                                     DataSentinel: A Game-Theoretic Detection of Prompt Injection Attacks
# 490                            Defending Language Models Against Image-Based Prompt Attacks via User-Provided Specifications
# 498                      Align Is Not Enough: Multimodal Universal Jailbreak Attack Against Multimodal Large Language Models
# 500                                         AudioJailbreak: Jailbreak Attacks Against End-to-End Large Audio-Language Models
# 501                                            RedAgent: An Autonomous Agent for Context-Aware Red Teaming of LLM Jailbreaks
# 503                                  MPDA: Multimodal Prompt Decoupling Attack on the Safety Filters in Text-to-Image Models
# 510                                                         Jailbreak Vision Language Models via Bi-Modal Adversarial Prompt
# 511               Disguise While Defense: Avoid Refusal Responses in LLM’s Defense via a Multi-Agent Attacker–Disguiser Game
# 531                                     Jailbreaking Multimodal Large Language Models via Consistent Cross-Modal Backgrounds
# 539                                                      A Multi-Agent LLM Defense Pipeline Against Prompt Injection Attacks
# 148                                                           MAJD: Intent-Aware Multi-Agent Framework for Jailbreak Defense
# 238                                Prompt Injection Detection and Mitigation with AI Multiagent NLP-based Agentic Frameworks
# 240                                    Evaluating Multi-Agent Defences Against Jailbreaking Attacks on Large Language Models
# 262                                                                  Secure Prompt Engineering Patterns for Cloud LLM Agents
# 286                    LLMS Do Not Always Say No: A Parallel Multi-Agent Jailbreak Framework Via Probabilistic Vulnerability
# 373                                          Prompt-to-SQL Injections in LLM-Integrated Web Applications: Risks and Defenses
# 469                                        Secure by Design: Quantifying Architectural Resilience and the Agents Rule of two
# 298                                                        Paper Summary Attack: Jailbreaking LLMs Through LLM Safety Papers
#
#     sources  year                                      doi  relevance_score  \
# 119  [IEEE]  2026              10.1109/access.2026.3726909             0.99
# 292  [IEEE]  2026        10.1109/icassp55912.2026.11463457             0.99
# 342  [IEEE]  2026        10.1109/ichora69329.2026.11536987             0.99
# 445  [IEEE]  2025   10.1109/optim-acemp62776.2025.11075247             0.99
# 456  [IEEE]  2025            10.1109/satml64287.2025.00011             0.99
# 259  [IEEE]  2026         10.1109/icaic67076.2026.11395696             0.99
# 90   [IEEE]  2026         10.1109/aaiml67890.2026.11498071             0.96
# 112  [IEEE]  2026              10.1109/access.2026.3700492             0.96
# 139  [IEEE]  2025         10.1109/aiita65135.2025.11047880             0.96
# 157  [IEEE]  2024       10.1109/bigdata62323.2024.10825099             0.96
# 208  [IEEE]  2025             10.1109/cvpr52734.2025.00884             0.96
# 209  [IEEE]  2025             10.1109/cvpr52734.2025.02331             0.96
# 210  [IEEE]  2025             10.1109/cvpr52734.2025.02786             0.96
# 220  [IEEE]  2025            10.1109/dsn-w65791.2025.00074             0.96
# 239  [IEEE]  2025          10.1109/fllm67465.2025.11391218             0.96
# 281  [IEEE]  2026        10.1109/icassp55912.2026.11461745             0.96
# 285  [IEEE]  2026        10.1109/icassp55912.2026.11462407             0.96
# 291  [IEEE]  2026        10.1109/icassp55912.2026.11463376             0.96
# 295  [IEEE]  2026        10.1109/icassp55912.2026.11464668             0.96
# 296  [IEEE]  2026        10.1109/icassp55912.2026.11464814             0.96
# 307  [IEEE]  2025         10.1109/iccit68739.2025.11491067             0.96
# 317  [IEEE]  2025             10.1109/iccv51701.2025.00198             0.96
# 318  [IEEE]  2025             10.1109/iccv51701.2025.00258             0.96
# 320  [IEEE]  2025             10.1109/iccv51701.2025.00830             0.96
# 324  [IEEE]  2026             10.1109/icdh72779.2026.00047             0.96
# 352  [IEEE]  2025          10.1109/icme59968.2025.11209893             0.96
# 353  [IEEE]  2025          10.1109/icme59968.2025.11210045             0.96
# 363  [IEEE]  2025        10.1109/iconat66879.2025.11362401             0.96
# 364  [IEEE]  2025          10.1109/icra55743.2025.11128119             0.96
# 394  [IEEE]  2025         10.1109/ijcnn64981.2025.11229281             0.96
# 396  [IEEE]  2026          10.1109/imns67862.2026.11655291             0.96
# 477  [IEEE]  2025               10.1109/sp61157.2025.00121             0.96
# 478  [IEEE]  2025               10.1109/sp61157.2025.00250             0.96
# 490  [IEEE]  2024              10.1109/spw63631.2024.00017             0.96
# 498  [IEEE]  2025               10.1109/tcsvt.2025.3526248             0.96
# 500  [IEEE]  2026                10.1109/tdsc.2026.3661073             0.96
# 501  [IEEE]  2026                10.1109/tdsc.2026.3665230             0.96
# 503  [IEEE]  2026                10.1109/tdsc.2026.3696145             0.96
# 510  [IEEE]  2025                10.1109/tifs.2025.3583249             0.96
# 511  [IEEE]  2026                10.1109/tifs.2025.3626228             0.96
# 531  [IEEE]  2025         10.1109/trustcom66490.2025.00263             0.96
# 539  [IEEE]  2025    10.1109/wiecon-ece69386.2025.11526251             0.96
# 148  [IEEE]  2025            10.1109/apsec66846.2025.00086             0.96
# 238  [IEEE]  2025          10.1109/fllm67465.2025.11391215             0.96
# 240  [IEEE]  2025          10.1109/fllm67465.2025.11391246             0.96
# 262  [IEEE]  2026         10.1109/icaic67076.2026.11395764             0.96
# 286  [IEEE]  2026        10.1109/icassp55912.2026.11462454             0.96
# 373  [IEEE]  2025             10.1109/icse55347.2025.00007             0.96
# 469  [IEEE]  2026  10.1109/southeastcon63549.2026.11475941             0.96
# 298  [IEEE]  2026        10.1109/icassp55912.2026.11465062             0.96
#
#      confidence                  study_type  \
# 119        0.99                   DETECTION
# 292        0.99  PRIMARY_ATTACK_AND_DEFENSE
# 342        0.99              PRIMARY_ATTACK
# 445        0.99  PRIMARY_ATTACK_AND_DEFENSE
# 456        0.99                   DETECTION
# 259        0.98              PRIMARY_ATTACK
# 90         0.99             PRIMARY_DEFENSE
# 112        0.99                      REVIEW
# 139        0.99                 RED_TEAMING
# 157        0.99             PRIMARY_DEFENSE
# 208        0.99              PRIMARY_ATTACK
# 209        0.99             PRIMARY_DEFENSE
# 210        0.99              PRIMARY_ATTACK
# 220        0.99              PRIMARY_ATTACK
# 239        0.99              PRIMARY_ATTACK
# 281        0.99             PRIMARY_DEFENSE
# 285        0.99              PRIMARY_ATTACK
# 291        0.99             PRIMARY_DEFENSE
# 295        0.99              PRIMARY_ATTACK
# 296        0.99              PRIMARY_ATTACK
# 307        0.99              PRIMARY_ATTACK
# 317        0.99              PRIMARY_ATTACK
# 318        0.99              PRIMARY_ATTACK
# 320        0.99              PRIMARY_ATTACK
# 324        0.99             PRIMARY_DEFENSE
# 352        0.99        BENCHMARK_EVALUATION
# 353        0.99              PRIMARY_ATTACK
# 363        0.99                      REVIEW
# 364        0.99              PRIMARY_ATTACK
# 394        0.99              PRIMARY_ATTACK
# 396        0.99                 RED_TEAMING
# 477        0.99              PRIMARY_ATTACK
# 478        0.99                   DETECTION
# 490        0.99             PRIMARY_DEFENSE
# 498        0.99              PRIMARY_ATTACK
# 500        0.99              PRIMARY_ATTACK
# 501        0.99                 RED_TEAMING
# 503        0.99              PRIMARY_ATTACK
# 510        0.99              PRIMARY_ATTACK
# 511        0.99             PRIMARY_DEFENSE
# 531        0.99              PRIMARY_ATTACK
# 539        0.99             PRIMARY_DEFENSE
# 148        0.98             PRIMARY_DEFENSE
# 238        0.98  PRIMARY_ATTACK_AND_DEFENSE
# 240        0.98             PRIMARY_DEFENSE
# 262        0.98             PRIMARY_DEFENSE
# 286        0.98              PRIMARY_ATTACK
# 373        0.98  PRIMARY_ATTACK_AND_DEFENSE
# 469        0.98  PRIMARY_ATTACK_AND_DEFENSE
# 298        0.97              PRIMARY_ATTACK
#
#                                                                                               contexts  \
# 119                                              [EXTERNAL_CONTENT, GENERAL_LLM, RAG, UNTRUSTED_INPUT]
# 292                                                                                 [GENERAL_LLM, RAG]
# 342  [DOCUMENT_PROCESSING, DOCUMENT_UNDERSTANDING, EXTERNAL_CONTENT, MULTIMODAL, RAG, UNTRUSTED_INPUT]
# 445         [EMAIL, EXTERNAL_CONTENT, GENERAL_LLM, HTML, INFORMATION_EXTRACTION, UNTRUSTED_INPUT, WEB]
# 456                                       [EMAIL, EXTERNAL_CONTENT, GENERAL_LLM, RAG, UNTRUSTED_INPUT]
# 259                               [CYBERSECURITY, EXTERNAL_CONTENT, GENERAL_LLM, RAG, UNTRUSTED_INPUT]
# 90                                                                                [AGENT, GENERAL_LLM]
# 112                                                        [AGENT, EXTERNAL_CONTENT, GENERAL_LLM, RAG]
# 139                                                                         [GENERAL_LLM, MULTI_AGENT]
# 157                                                                          [GENERAL_LLM, MULTIMODAL]
# 208                                                                          [GENERAL_LLM, MULTIMODAL]
# 209                                                                          [GENERAL_LLM, MULTIMODAL]
# 210                                                                          [GENERAL_LLM, MULTIMODAL]
# 220                                                                          [GENERAL_LLM, MULTIMODAL]
# 239                                                                          [GENERAL_LLM, MULTIMODAL]
# 281                                                   [EXTERNAL_CONTENT, GENERAL_LLM, UNTRUSTED_INPUT]
# 285                                                                               [AGENT, GENERAL_LLM]
# 291                                                         [AGENT, EXTERNAL_CONTENT, UNTRUSTED_INPUT]
# 295                                                                          [GENERAL_LLM, MULTIMODAL]
# 296                                                                          [GENERAL_LLM, MULTIMODAL]
# 307                                    [CYBERSECURITY, EXTERNAL_CONTENT, GENERAL_LLM, UNTRUSTED_INPUT]
# 317                                                                          [GENERAL_LLM, MULTIMODAL]
# 318                                                                          [GENERAL_LLM, MULTIMODAL]
# 320                                                                          [GENERAL_LLM, MULTIMODAL]
# 324        [AGENT, CYBERSECURITY, DOCUMENT_PROCESSING, EXTERNAL_CONTENT, MULTI_AGENT, UNTRUSTED_INPUT]
# 352                                                                          [GENERAL_LLM, MULTIMODAL]
# 353                                                                          [GENERAL_LLM, MULTIMODAL]
# 363                                                        [EXTERNAL_CONTENT, GENERAL_LLM, MULTIMODAL]
# 364                                                                               [AGENT, GENERAL_LLM]
# 394                                                                          [GENERAL_LLM, MULTIMODAL]
# 396                                          [AGENT, CYBERSECURITY, EXTERNAL_CONTENT, UNTRUSTED_INPUT]
# 477                                                      [CYBERSECURITY, GENERAL_LLM, UNTRUSTED_INPUT]
# 478                                               [AGENT, CYBERSECURITY, GENERAL_LLM, UNTRUSTED_INPUT]
# 490                                                [CHATBOT, GENERAL_LLM, MULTIMODAL, UNTRUSTED_INPUT]
# 498                                                                          [GENERAL_LLM, MULTIMODAL]
# 500                                                           [CYBERSECURITY, GENERAL_LLM, MULTIMODAL]
# 501                                                                [AGENT, CYBERSECURITY, GENERAL_LLM]
# 503                                                                          [GENERAL_LLM, MULTIMODAL]
# 510                                                                          [GENERAL_LLM, MULTIMODAL]
# 511                                                             [AGENT, GENERAL_LLM, MULTI_AGENT, WEB]
# 531                                                                          [GENERAL_LLM, MULTIMODAL]
# 539                                  [AGENT, CYBERSECURITY, GENERAL_LLM, MULTI_AGENT, UNTRUSTED_INPUT]
# 148                                                         [AGENT, CHATBOT, GENERAL_LLM, MULTI_AGENT]
# 238                                                                  [AGENT, GENERAL_LLM, MULTI_AGENT]
# 240                                                                         [GENERAL_LLM, MULTI_AGENT]
# 262                                               [AGENT, CYBERSECURITY, GENERAL_LLM, UNTRUSTED_INPUT]
# 286                                                                         [GENERAL_LLM, MULTI_AGENT]
# 373                                                 [CYBERSECURITY, GENERAL_LLM, UNTRUSTED_INPUT, WEB]
# 469                                                         [AGENT, EXTERNAL_CONTENT, UNTRUSTED_INPUT]
# 298                                                                    [EXTERNAL_CONTENT, GENERAL_LLM]
#
#                                                    contribution_types  \
# 119                     [DETECTION, EVALUATION, FORENSICS, FRAMEWORK]
# 292                         [ATTACK, DEFENSE, EVALUATION, MITIGATION]
# 342                                              [ATTACK, EVALUATION]
# 445     [ATTACK, BENCHMARK, DATASET, DEFENSE, EVALUATION, MITIGATION]
# 456              [DATASET, DEFENSE, DETECTION, EVALUATION, FRAMEWORK]
# 259                                              [ATTACK, EVALUATION]
# 90            [DEFENSE, DETECTION, EVALUATION, FRAMEWORK, MITIGATION]
# 112                                    [EVALUATION, REVIEW, TAXONOMY]
# 139                      [ATTACK, EVALUATION, FRAMEWORK, RED_TEAMING]
# 157                                 [DEFENSE, EVALUATION, MITIGATION]
# 208                                   [ATTACK, EVALUATION, FRAMEWORK]
# 209                      [DEFENSE, EVALUATION, FRAMEWORK, MITIGATION]
# 210                                   [ATTACK, EVALUATION, FRAMEWORK]
# 220                                 [ATTACK, EVALUATION, RED_TEAMING]
# 239                                   [ATTACK, EVALUATION, FRAMEWORK]
# 281                      [DEFENSE, DETECTION, EVALUATION, MITIGATION]
# 285                                   [ATTACK, EVALUATION, FRAMEWORK]
# 291                      [DEFENSE, DETECTION, EVALUATION, MITIGATION]
# 295                                              [ATTACK, EVALUATION]
# 296                                              [ATTACK, EVALUATION]
# 307                          [ATTACK, BENCHMARK, DATASET, EVALUATION]
# 317                                              [ATTACK, EVALUATION]
# 318                                              [ATTACK, EVALUATION]
# 320  [ATTACK, BENCHMARK, DATASET, EVALUATION, FRAMEWORK, RED_TEAMING]
# 324                                 [DEFENSE, EVALUATION, MITIGATION]
# 352                          [ATTACK, BENCHMARK, DATASET, EVALUATION]
# 353                                              [ATTACK, EVALUATION]
# 363                           [DEFENSE, MITIGATION, REVIEW, TAXONOMY]
# 364                          [ATTACK, BENCHMARK, DATASET, EVALUATION]
# 394                                              [ATTACK, EVALUATION]
# 396                                 [ATTACK, EVALUATION, RED_TEAMING]
# 477                                              [ATTACK, EVALUATION]
# 478                       [DEFENSE, DETECTION, EVALUATION, FRAMEWORK]
# 490           [DEFENSE, DETECTION, EVALUATION, FRAMEWORK, PREVENTION]
# 498                                              [ATTACK, EVALUATION]
# 500                                              [ATTACK, EVALUATION]
# 501                      [ATTACK, EVALUATION, FRAMEWORK, RED_TEAMING]
# 503                                              [ATTACK, EVALUATION]
# 510                                 [ATTACK, EVALUATION, RED_TEAMING]
# 511                      [DEFENSE, EVALUATION, FRAMEWORK, MITIGATION]
# 531                                              [ATTACK, EVALUATION]
# 539           [DEFENSE, DETECTION, EVALUATION, FRAMEWORK, MITIGATION]
# 148           [DEFENSE, DETECTION, EVALUATION, FRAMEWORK, MITIGATION]
# 238           [DEFENSE, DETECTION, EVALUATION, FRAMEWORK, MITIGATION]
# 240                                 [DEFENSE, EVALUATION, MITIGATION]
# 262           [DEFENSE, EVALUATION, MITIGATION, PREVENTION, TAXONOMY]
# 286                                   [ATTACK, EVALUATION, FRAMEWORK]
# 373             [ATTACK, DEFENSE, EVALUATION, MITIGATION, PREVENTION]
# 469                         [ATTACK, DEFENSE, EVALUATION, MITIGATION]
# 298                                              [ATTACK, EVALUATION]
#
#                                                                                                                       reason
# 119  O trabalho é diretamente centrado em indirect prompt injection e rastreia sua propagação de fontes e contextos recup...
# 292  DarkCite propõe um jailbreak black-box baseado em autoridade e citações fabricadas, interpretado como forma de RAG i...
# 342  Investiga diretamente prompt injection indireta visual e estrutural em RAG médico, incluindo white-text, microtipogr...
# 445  O estudo investiga diretamente prompt injection oculto em HTML durante extração de informações de fontes web e e-mai...
# 456  O artigo aborda diretamente prompt injection causada por instruções presentes em dados externos não confiáveis de ap...
# 259  O estudo investiga diretamente prompt injection em RAG por meio de documentos maliciosos recuperados e propõe o ataq...
# 90   Foca em prompt theft como variante de ataque relacionada a prompt injection e propõe filtro pós-inferência por simil...
# 112  Revisão sistemática diretamente centrada em prompt injection, com PRISMA, 81 estudos analisados e classificação por ...
# 139  O estudo apresenta um framework multiagente para gerar automaticamente prompts de jailbreak contra LLMs black-box, c...
# 157  Propõe explicitamente uma defesa para modelos visão-linguagem contra jailbreaks e ataques adversariais mediante ajus...
# 208  Propõe um novo mecanismo de jailbreak multimodal baseado em distração estruturada e visual para degradar a detecção ...
# 209  O artigo propõe diretamente uma defesa em tempo de inferência contra jailbreaks em MLLMs usando modelo de recompensa...
# 210  Investiga diretamente uma vulnerabilidade de alinhamento e propõe JOOD, um framework de jailbreak baseado em transfo...
# 220  O trabalho introduz um novo jailbreak em áudio baseado em manipulação de tokens de fala para contornar salvaguardas ...
# 239  Image-based prompt injection is the central phenomenon. The paper presents an end-to-end black-box attack pipeline a...
# 281  O artigo trata diretamente de indirect prompt injection e propõe detecção, localização e remoção das instruções inje...
# 285  PINA investiga diretamente prompt injection em agentes de navegação LLM sob restrições black-box, long-context e exe...
# 291  O estudo aborda diretamente indirect prompt injection em agentes LLM que consomem fontes externas não confiáveis e p...
# 295  CAS-J é um ataque de jailbreak multimodal que manipula interações internas de atenção entre texto e imagem para cont...
# 296  O estudo propõe um jailbreak multimodal áudio-texto contra modelos áudio-linguagem, combinando perturbações adversar...
# 307  O estudo introduz um jailbreak por instruções proibidas ocultas em comentários de código e o testa em 1.800 gerações...
# 317  O artigo propõe o SI-Attack, um jailbreak multimodal black-box que explora inconsistência entre compreensão e segura...
# 318  O trabalho apresenta um jailbreak black-box multimodal que distribui semântica maliciosa entre modalidades e usa bus...
# 320  O estudo propõe geração automatizada de pares imagem-texto maliciosos para jailbreak black-box, usa VLMs como red te...
# 324  O estudo avalia uma arquitetura de contenção para agentes clínicos sob payloads de prompt injection embutidos em rel...
# 352  O artigo introduz o dataset FlowJD para avaliar jailbreak por fluxogramas em modelos visão-linguagem e testa nove mo...
# 353  O trabalho propõe um framework de jailbreak multimodal que combina ataques tipográficos visuais e contextualização e...
# 363  A revisão estruturada é centrada em jailbreak e prompt injection e propõe taxonomia por objetivo e execução, incluin...
# 364  Introduz um algoritmo específico para jailbreak de robôs controlados por LLMs e o avalia em cenários white-box, gray...
# 394  O artigo propõe um ataque de jailbreak multimodal em cenário black-box por otimização de alinhamento em espaços de e...
# 396  O estudo realiza red teaming sistemático de um agente de pagamentos e introduz dois ataques de prompt injection, inc...
# 477  O artigo identifica um novo vetor para calcular prompt injections otimizadas explorando informações retornadas por i...
# 478  Prompt injection é o foco explícito e o DataSentinel propõe detecção robusta inclusive contra ataques adaptativos po...
# 490  O artigo trata diretamente de ataques de prompt injection baseados em imagens e propõe uma defesa em duas etapas com...
# 498  O estudo propõe um ataque universal multimodal de jailbreak que combina interações imagem-texto, sufixo adversarial ...
# 500  O artigo propõe um novo jailbreak em áudio com propriedades de assincronia, universalidade, furtividade e robustez o...
# 501  O trabalho propõe um agente autônomo para gerar jailbreaks específicos ao contexto de aplicações LLM, utilizando inf...
# 503  O estudo propõe um jailbreak multimodal que combina reescrita de prompts e entrada visual para contornar filtros de ...
# 510  O artigo propõe um ataque de jailbreak bimodal que otimiza conjuntamente prompts visuais e textuais em modelos visão...
# 511  O estudo propõe uma defesa específica contra prompts de jailbreak por meio de um jogo multiagente atacante-disfarçad...
# 531  Propõe um novo jailbreak multimodal que usa pistas de fundo semanticamente consistentes em imagem e texto para desvi...
# 539  O trabalho apresenta uma defesa multiagente especificamente contra prompt injection e a avalia em 400 instâncias, oi...
# 148  Jailbreak defense is the core contribution. The multi-agent framework targets single-turn and multi-turn attacks and...
# 238  Prompt injection detection and mitigation are the central contributions. The multi-agent framework is empirically ev...
# 240  The study directly evaluates multi-agent defenses against multiple jailbreak strategies. It compares single-, two-, ...
# 262  Prompt injection em agentes LLM de nuvem é o foco principal, incluindo vetores diretos e indiretos e padrões de defe...
# 286  Propõe um framework de jailbreak multiagente que explora a variabilidade probabilística das respostas para elevar a ...
# 373  O artigo caracteriza ataques prompt-to-SQL em aplicações web integradas a LLMs, analisa variantes e impactos e propõ...
# 469  Avalia diretamente padrões arquiteturais de defesa contra indirect prompt injection em agentes e inclui vetores como...
# 298  Propõe um novo método de jailbreak que utiliza conteúdo sintetizado de artigos de segurança como parte do prompt adv...

# %% [markdown]
# ## Ranking atual

# %%
top_ranked = (
    evaluated_studies.loc[evaluated_studies["hard_exclude"] == False]
    .sort_values(["relevance_score", "confidence"], ascending=[False, False])
)

display(
    top_ranked[
        [
            "title",
            "sources",
            "year",
            "doi",
            "relevance_score",
            "confidence",
            "study_type",
            "contexts",
            "contribution_types",
            "reason",
        ]
    ].head(30)
)
# Out:
#                                                                                                                        title  \
# 119         TrustTrace: Provenance-Aware Tracing of Indirect Prompt Injection Propagation in LLM-Assisted Learning Workflows
# 445                             Disrupting Large Language Models with Hidden Prompt Injection Attacks Embedded in HTML Pages
# 456                                                             Get My Drift? Catching LLM Task Drift with Activation Deltas
# 259                                      Zero-Shot Tokenizer Transfer for Targeted Attacks on Retrieval-Augmented Generation
# 139                                     Automatically Generated Multi-Agent Framework for Jailbreaking Large Language Models
# 157                          Securing Vision-Language Models with a Robust Encoder Against Jailbreak and Adversarial Attacks
# 208                                             Distraction is All You Need for Multimodal Large Language Model Jailbreaking
# 209                             Immune: Improving Safety Against Jailbreaks in Multi-modal LLMs via Inference-Time Alignment
# 210                                Playing the Fool: Jailbreaking LLMs and Multimodal LLMs with Out-of-Distribution Strategy
# 220                                  Audio Jailbreak Attacks: Exposing Vulnerabilities in SpeechGPT in a White-Box Framework
# 239               Image-based Prompt Injection: Hijacking Multimodal LLMs through Visually Embedded Adversarial Instructions
# 281                             ATTN-Defense: Attention-Guided Detection, Location and Removal for Indirect Prompt Injection
# 291                  IPI2: Mitigating Indirect Prompt Injections on Unmanned Aerial Vehicle Agents Using Physical Invariants
# 307                  Code Poisoning Through Misleading Comments: Jailbreaking Large Language Models via Contextual Deception
# 317                                                  Jailbreaking Multimodal Large Language Models via Shuffle Inconsistency
# 318                     Heuristic-Induced Multimodal Risk Distribution Jailbreak Attack for Multimodal Large Language Models
# 320                                     Ideator: Jailbreaking and Benchmarking Large Vision-Language Models Using Themselves
# 324               Securing Autonomous Clinical Agents: Time-Scoped Hypergraph Delegation for Controlling Patient Data Access
# 352                                                FlowJD: Your Imagination Can Help You Jailbreak in Visual Language Models
# 353                                 PiCo: Jailbreaking Multimodal Large Language Models via Pictorial Code Contextualization
# 363                         The Dark Side of AI: a Systematization of Knowledge on Jailbreaking and Prompt Injection in LLMs
# 364                                                                                       Jailbreaking LLM-Controlled Robots
# 394                                 DEO: Jailbreak a Black-box Multimodal Large Language Model with Dual-Embedding Alignment
# 396                                  Whispers of Wealth: A Systematic Red-Teaming Study of the Agent Payments Protocol (AP2)
# 477  Fun-tuning: Characterizing the Vulnerability of Proprietary LLMs to Optimization-Based Prompt Injection Attacks via ...
# 478                                                     DataSentinel: A Game-Theoretic Detection of Prompt Injection Attacks
# 490                            Defending Language Models Against Image-Based Prompt Attacks via User-Provided Specifications
# 498                      Align Is Not Enough: Multimodal Universal Jailbreak Attack Against Multimodal Large Language Models
# 500                                         AudioJailbreak: Jailbreak Attacks Against End-to-End Large Audio-Language Models
# 501                                            RedAgent: An Autonomous Agent for Context-Aware Red Teaming of LLM Jailbreaks
#
#     sources  year                                     doi  relevance_score  \
# 119  [IEEE]  2026             10.1109/access.2026.3726909             0.99
# 445  [IEEE]  2025  10.1109/optim-acemp62776.2025.11075247             0.99
# 456  [IEEE]  2025           10.1109/satml64287.2025.00011             0.99
# 259  [IEEE]  2026        10.1109/icaic67076.2026.11395696             0.99
# 139  [IEEE]  2025        10.1109/aiita65135.2025.11047880             0.96
# 157  [IEEE]  2024      10.1109/bigdata62323.2024.10825099             0.96
# 208  [IEEE]  2025            10.1109/cvpr52734.2025.00884             0.96
# 209  [IEEE]  2025            10.1109/cvpr52734.2025.02331             0.96
# 210  [IEEE]  2025            10.1109/cvpr52734.2025.02786             0.96
# 220  [IEEE]  2025           10.1109/dsn-w65791.2025.00074             0.96
# 239  [IEEE]  2025         10.1109/fllm67465.2025.11391218             0.96
# 281  [IEEE]  2026       10.1109/icassp55912.2026.11461745             0.96
# 291  [IEEE]  2026       10.1109/icassp55912.2026.11463376             0.96
# 307  [IEEE]  2025        10.1109/iccit68739.2025.11491067             0.96
# 317  [IEEE]  2025            10.1109/iccv51701.2025.00198             0.96
# 318  [IEEE]  2025            10.1109/iccv51701.2025.00258             0.96
# 320  [IEEE]  2025            10.1109/iccv51701.2025.00830             0.96
# 324  [IEEE]  2026            10.1109/icdh72779.2026.00047             0.96
# 352  [IEEE]  2025         10.1109/icme59968.2025.11209893             0.96
# 353  [IEEE]  2025         10.1109/icme59968.2025.11210045             0.96
# 363  [IEEE]  2025       10.1109/iconat66879.2025.11362401             0.96
# 364  [IEEE]  2025         10.1109/icra55743.2025.11128119             0.96
# 394  [IEEE]  2025        10.1109/ijcnn64981.2025.11229281             0.96
# 396  [IEEE]  2026         10.1109/imns67862.2026.11655291             0.96
# 477  [IEEE]  2025              10.1109/sp61157.2025.00121             0.96
# 478  [IEEE]  2025              10.1109/sp61157.2025.00250             0.96
# 490  [IEEE]  2024             10.1109/spw63631.2024.00017             0.96
# 498  [IEEE]  2025              10.1109/tcsvt.2025.3526248             0.96
# 500  [IEEE]  2026               10.1109/tdsc.2026.3661073             0.96
# 501  [IEEE]  2026               10.1109/tdsc.2026.3665230             0.96
#
#      confidence                  study_type  \
# 119        0.99                   DETECTION
# 445        0.99  PRIMARY_ATTACK_AND_DEFENSE
# 456        0.99                   DETECTION
# 259        0.98              PRIMARY_ATTACK
# 139        0.99                 RED_TEAMING
# 157        0.99             PRIMARY_DEFENSE
# 208        0.99              PRIMARY_ATTACK
# 209        0.99             PRIMARY_DEFENSE
# 210        0.99              PRIMARY_ATTACK
# 220        0.99              PRIMARY_ATTACK
# 239        0.99              PRIMARY_ATTACK
# 281        0.99             PRIMARY_DEFENSE
# 291        0.99             PRIMARY_DEFENSE
# 307        0.99              PRIMARY_ATTACK
# 317        0.99              PRIMARY_ATTACK
# 318        0.99              PRIMARY_ATTACK
# 320        0.99              PRIMARY_ATTACK
# 324        0.99             PRIMARY_DEFENSE
# 352        0.99        BENCHMARK_EVALUATION
# 353        0.99              PRIMARY_ATTACK
# 363        0.99                      REVIEW
# 364        0.99              PRIMARY_ATTACK
# 394        0.99              PRIMARY_ATTACK
# 396        0.99                 RED_TEAMING
# 477        0.99              PRIMARY_ATTACK
# 478        0.99                   DETECTION
# 490        0.99             PRIMARY_DEFENSE
# 498        0.99              PRIMARY_ATTACK
# 500        0.99              PRIMARY_ATTACK
# 501        0.99                 RED_TEAMING
#
#                                                                                         contexts  \
# 119                                        [EXTERNAL_CONTENT, GENERAL_LLM, RAG, UNTRUSTED_INPUT]
# 445   [EMAIL, EXTERNAL_CONTENT, GENERAL_LLM, HTML, INFORMATION_EXTRACTION, UNTRUSTED_INPUT, WEB]
# 456                                 [EMAIL, EXTERNAL_CONTENT, GENERAL_LLM, RAG, UNTRUSTED_INPUT]
# 259                         [CYBERSECURITY, EXTERNAL_CONTENT, GENERAL_LLM, RAG, UNTRUSTED_INPUT]
# 139                                                                   [GENERAL_LLM, MULTI_AGENT]
# 157                                                                    [GENERAL_LLM, MULTIMODAL]
# 208                                                                    [GENERAL_LLM, MULTIMODAL]
# 209                                                                    [GENERAL_LLM, MULTIMODAL]
# 210                                                                    [GENERAL_LLM, MULTIMODAL]
# 220                                                                    [GENERAL_LLM, MULTIMODAL]
# 239                                                                    [GENERAL_LLM, MULTIMODAL]
# 281                                             [EXTERNAL_CONTENT, GENERAL_LLM, UNTRUSTED_INPUT]
# 291                                                   [AGENT, EXTERNAL_CONTENT, UNTRUSTED_INPUT]
# 307                              [CYBERSECURITY, EXTERNAL_CONTENT, GENERAL_LLM, UNTRUSTED_INPUT]
# 317                                                                    [GENERAL_LLM, MULTIMODAL]
# 318                                                                    [GENERAL_LLM, MULTIMODAL]
# 320                                                                    [GENERAL_LLM, MULTIMODAL]
# 324  [AGENT, CYBERSECURITY, DOCUMENT_PROCESSING, EXTERNAL_CONTENT, MULTI_AGENT, UNTRUSTED_INPUT]
# 352                                                                    [GENERAL_LLM, MULTIMODAL]
# 353                                                                    [GENERAL_LLM, MULTIMODAL]
# 363                                                  [EXTERNAL_CONTENT, GENERAL_LLM, MULTIMODAL]
# 364                                                                         [AGENT, GENERAL_LLM]
# 394                                                                    [GENERAL_LLM, MULTIMODAL]
# 396                                    [AGENT, CYBERSECURITY, EXTERNAL_CONTENT, UNTRUSTED_INPUT]
# 477                                                [CYBERSECURITY, GENERAL_LLM, UNTRUSTED_INPUT]
# 478                                         [AGENT, CYBERSECURITY, GENERAL_LLM, UNTRUSTED_INPUT]
# 490                                          [CHATBOT, GENERAL_LLM, MULTIMODAL, UNTRUSTED_INPUT]
# 498                                                                    [GENERAL_LLM, MULTIMODAL]
# 500                                                     [CYBERSECURITY, GENERAL_LLM, MULTIMODAL]
# 501                                                          [AGENT, CYBERSECURITY, GENERAL_LLM]
#
#                                                    contribution_types  \
# 119                     [DETECTION, EVALUATION, FORENSICS, FRAMEWORK]
# 445     [ATTACK, BENCHMARK, DATASET, DEFENSE, EVALUATION, MITIGATION]
# 456              [DATASET, DEFENSE, DETECTION, EVALUATION, FRAMEWORK]
# 259                                              [ATTACK, EVALUATION]
# 139                      [ATTACK, EVALUATION, FRAMEWORK, RED_TEAMING]
# 157                                 [DEFENSE, EVALUATION, MITIGATION]
# 208                                   [ATTACK, EVALUATION, FRAMEWORK]
# 209                      [DEFENSE, EVALUATION, FRAMEWORK, MITIGATION]
# 210                                   [ATTACK, EVALUATION, FRAMEWORK]
# 220                                 [ATTACK, EVALUATION, RED_TEAMING]
# 239                                   [ATTACK, EVALUATION, FRAMEWORK]
# 281                      [DEFENSE, DETECTION, EVALUATION, MITIGATION]
# 291                      [DEFENSE, DETECTION, EVALUATION, MITIGATION]
# 307                          [ATTACK, BENCHMARK, DATASET, EVALUATION]
# 317                                              [ATTACK, EVALUATION]
# 318                                              [ATTACK, EVALUATION]
# 320  [ATTACK, BENCHMARK, DATASET, EVALUATION, FRAMEWORK, RED_TEAMING]
# 324                                 [DEFENSE, EVALUATION, MITIGATION]
# 352                          [ATTACK, BENCHMARK, DATASET, EVALUATION]
# 353                                              [ATTACK, EVALUATION]
# 363                           [DEFENSE, MITIGATION, REVIEW, TAXONOMY]
# 364                          [ATTACK, BENCHMARK, DATASET, EVALUATION]
# 394                                              [ATTACK, EVALUATION]
# 396                                 [ATTACK, EVALUATION, RED_TEAMING]
# 477                                              [ATTACK, EVALUATION]
# 478                       [DEFENSE, DETECTION, EVALUATION, FRAMEWORK]
# 490           [DEFENSE, DETECTION, EVALUATION, FRAMEWORK, PREVENTION]
# 498                                              [ATTACK, EVALUATION]
# 500                                              [ATTACK, EVALUATION]
# 501                      [ATTACK, EVALUATION, FRAMEWORK, RED_TEAMING]
#
#                                                                                                                       reason
# 119  O trabalho é diretamente centrado em indirect prompt injection e rastreia sua propagação de fontes e contextos recup...
# 445  O estudo investiga diretamente prompt injection oculto em HTML durante extração de informações de fontes web e e-mai...
# 456  O artigo aborda diretamente prompt injection causada por instruções presentes em dados externos não confiáveis de ap...
# 259  O estudo investiga diretamente prompt injection em RAG por meio de documentos maliciosos recuperados e propõe o ataq...
# 139  O estudo apresenta um framework multiagente para gerar automaticamente prompts de jailbreak contra LLMs black-box, c...
# 157  Propõe explicitamente uma defesa para modelos visão-linguagem contra jailbreaks e ataques adversariais mediante ajus...
# 208  Propõe um novo mecanismo de jailbreak multimodal baseado em distração estruturada e visual para degradar a detecção ...
# 209  O artigo propõe diretamente uma defesa em tempo de inferência contra jailbreaks em MLLMs usando modelo de recompensa...
# 210  Investiga diretamente uma vulnerabilidade de alinhamento e propõe JOOD, um framework de jailbreak baseado em transfo...
# 220  O trabalho introduz um novo jailbreak em áudio baseado em manipulação de tokens de fala para contornar salvaguardas ...
# 239  Image-based prompt injection is the central phenomenon. The paper presents an end-to-end black-box attack pipeline a...
# 281  O artigo trata diretamente de indirect prompt injection e propõe detecção, localização e remoção das instruções inje...
# 291  O estudo aborda diretamente indirect prompt injection em agentes LLM que consomem fontes externas não confiáveis e p...
# 307  O estudo introduz um jailbreak por instruções proibidas ocultas em comentários de código e o testa em 1.800 gerações...
# 317  O artigo propõe o SI-Attack, um jailbreak multimodal black-box que explora inconsistência entre compreensão e segura...
# 318  O trabalho apresenta um jailbreak black-box multimodal que distribui semântica maliciosa entre modalidades e usa bus...
# 320  O estudo propõe geração automatizada de pares imagem-texto maliciosos para jailbreak black-box, usa VLMs como red te...
# 324  O estudo avalia uma arquitetura de contenção para agentes clínicos sob payloads de prompt injection embutidos em rel...
# 352  O artigo introduz o dataset FlowJD para avaliar jailbreak por fluxogramas em modelos visão-linguagem e testa nove mo...
# 353  O trabalho propõe um framework de jailbreak multimodal que combina ataques tipográficos visuais e contextualização e...
# 363  A revisão estruturada é centrada em jailbreak e prompt injection e propõe taxonomia por objetivo e execução, incluin...
# 364  Introduz um algoritmo específico para jailbreak de robôs controlados por LLMs e o avalia em cenários white-box, gray...
# 394  O artigo propõe um ataque de jailbreak multimodal em cenário black-box por otimização de alinhamento em espaços de e...
# 396  O estudo realiza red teaming sistemático de um agente de pagamentos e introduz dois ataques de prompt injection, inc...
# 477  O artigo identifica um novo vetor para calcular prompt injections otimizadas explorando informações retornadas por i...
# 478  Prompt injection é o foco explícito e o DataSentinel propõe detecção robusta inclusive contra ataques adaptativos po...
# 490  O artigo trata diretamente de ataques de prompt injection baseados em imagens e propõe uma defesa em duas etapas com...
# 498  O estudo propõe um ataque universal multimodal de jailbreak que combina interações imagem-texto, sufixo adversarial ...
# 500  O artigo propõe um novo jailbreak em áudio com propriedades de assincronia, universalidade, furtividade e robustez o...
# 501  O trabalho propõe um agente autônomo para gerar jailbreaks específicos ao contexto de aplicações LLM, utilizando inf...

# %% [markdown]
# ## Pendências

# %%
pending = (
    studies.loc[studies["screening_status"] == "PENDING"]
    .sort_values(["sources", "title"])
    .copy()
)

print("Estudos únicos pendentes:", len(pending))
display(pending[["title", "sources", "year", "doi", "url"]].head(50))

# %% [markdown]
# ## Resumo por base

# %%
rows = []

for database, group in combined.groupby("database"):
    eg = group.loc[group["screening_status"] == "EVALUATED"]
    scores = pd.to_numeric(eg["relevance_score"], errors="coerce")

    rows.append({
        "database": database,
        "records_total": len(group),
        "evaluated": len(eg),
        "pending": (group["screening_status"] == "PENDING").sum(),
        "hard_exclude": eg["hard_exclude"].fillna(False).sum() if len(eg) else 0,
        "mean_score": scores.mean() if len(eg) else None,
        "median_score": scores.median() if len(eg) else None,
        "score_ge_threshold": (scores >= FULL_TEXT_THRESHOLD).sum() if len(eg) else 0,
    })

database_summary = pd.DataFrame(rows)
display(database_summary)

# %% [markdown]
# ## Exportar arquivos

# %%
threshold_tag = str(FULL_TEXT_THRESHOLD).replace(".", "_")

combined.to_csv(
    OUTPUT_DIR / "all_records_with_screening.csv",
    index=False,
    encoding="utf-8-sig",
)

studies.to_csv(
    OUTPUT_DIR / "master_studies_deduplicated.csv",
    index=False,
    encoding="utf-8-sig",
)

top_ranked.to_csv(
    OUTPUT_DIR / "ranked_evaluated_studies.csv",
    index=False,
    encoding="utf-8-sig",
)

full_text_candidates.to_csv(
    OUTPUT_DIR / f"full_text_candidates_{threshold_tag}.csv",
    index=False,
    encoding="utf-8-sig",
)

gray_zone.to_csv(
    OUTPUT_DIR / f"manual_review_zone_{threshold_tag}.csv",
    index=False,
    encoding="utf-8-sig",
)

pending.to_csv(
    OUTPUT_DIR / "pending_screening.csv",
    index=False,
    encoding="utf-8-sig",
)

duplicates.to_csv(
    OUTPUT_DIR / "possible_duplicates.csv",
    index=False,
    encoding="utf-8-sig",
)

invalid_scores.to_csv(
    OUTPUT_DIR / "screening_validation_issues.csv",
    index=False,
    encoding="utf-8-sig",
)

database_summary.to_csv(
    OUTPUT_DIR / "summary_by_database.csv",
    index=False,
    encoding="utf-8-sig",
)

print("Arquivos gerados em:", OUTPUT_DIR.resolve())
for p in sorted(OUTPUT_DIR.glob("*.csv")):
    print(" -", p.name)

# %% [markdown]
# ## Uso metodológico
#
# Enquanto o screening estiver incompleto, use o notebook apenas para:
#
# - acompanhar quantos estudos já foram avaliados;
# - observar a distribuição dos scores;
# - verificar erros de cálculo;
# - identificar duplicatas;
# - observar tipos de estudos, contextos e contribuições;
# - experimentar diferentes pontos de corte.
#
# O corte definitivo para leitura integral deve ser definido somente depois que as bases planejadas tiverem sido processadas.
#
# O arquivo central para a fase seguinte será:
#
# `analysis_outputs/master_studies_deduplicated.csv`

# %%
# ============================================================
# GERAR CSV FINAL CONSOLIDADO
# ============================================================

final_df = studies.copy()

# ------------------------------------------------------------
# 1. Criar status de decisão provisória
# ------------------------------------------------------------

def classify_screening(row):
    if row["screening_status"] == "PENDING":
        return "PENDING"

    if row["hard_exclude"] == True:
        return "HARD_EXCLUDE"

    score = row["relevance_score"]

    if pd.isna(score):
        return "PENDING"

    if score >= FULL_TEXT_THRESHOLD:
        return "FULL_TEXT_CANDIDATE"

    if score >= (FULL_TEXT_THRESHOLD - GRAY_ZONE_MARGIN):
        return "MANUAL_REVIEW"

    return "BELOW_THRESHOLD"


final_df["selection_status"] = final_df.apply(
    classify_screening,
    axis=1
)


# ------------------------------------------------------------
# 2. Criar ranking
# ------------------------------------------------------------

# Ranking somente entre estudos avaliados e não hard-excluded
eligible_mask = (
    (final_df["screening_status"] == "EVALUATED")
    & (final_df["hard_exclude"] == False)
)

final_df["relevance_rank"] = pd.NA

final_df.loc[
    eligible_mask,
    "relevance_rank"
] = (
    final_df.loc[
        eligible_mask,
        "relevance_score"
    ]
    .rank(
        method="min",
        ascending=False
    )
    .astype("Int64")
)


# ------------------------------------------------------------
# 3. Converter campos que são listas para texto legível no CSV
# ------------------------------------------------------------

def list_to_text(value):
    if isinstance(value, list):
        return "; ".join(map(str, value))
    return value


for column in [
    "sources",
    "contexts",
    "contribution_types",
]:
    if column in final_df.columns:
        final_df[column] = final_df[column].apply(
            list_to_text
        )


# ------------------------------------------------------------
# 4. Organizar as colunas
# ------------------------------------------------------------

preferred_columns = [
    "relevance_rank",
    "selection_status",
    "relevance_score",
    "confidence",

    "title",
    "authors",
    "year",
    "doi",
    "url",
    "venue",

    "sources",
    "source_count",

    "study_type",
    "contribution_types",
    "contexts",

    "hard_exclude",
    "screening_status",

    "n_evaluations",
    "score_range_if_repeated",

    "reason",
    "abstract",

    "study_key",
]

# Mantém somente colunas existentes
preferred_columns = [
    col
    for col in preferred_columns
    if col in final_df.columns
]

final_df = final_df[
    preferred_columns
].copy()


# ------------------------------------------------------------
# 5. Definir ordem dos status
# ------------------------------------------------------------

status_order = {
    "FULL_TEXT_CANDIDATE": 1,
    "MANUAL_REVIEW": 2,
    "BELOW_THRESHOLD": 3,
    "HARD_EXCLUDE": 4,
    "PENDING": 5,
}

final_df["_status_order"] = (
    final_df["selection_status"]
    .map(status_order)
    .fillna(99)
)


# ------------------------------------------------------------
# 6. Ordenar
# ------------------------------------------------------------

final_df = (
    final_df
    .sort_values(
        by=[
            "_status_order",
            "relevance_score",
            "confidence",
        ],
        ascending=[
            True,
            False,
            False,
        ],
        na_position="last",
    )
    .drop(
        columns="_status_order"
    )
    .reset_index(drop=True)
)


# ------------------------------------------------------------
# 7. Exportar
# ------------------------------------------------------------

output_file = (
    OUTPUT_DIR
    / "FINAL_screening_studies.csv"
)

final_df.to_csv(
    output_file,
    index=False,
    encoding="utf-8-sig",
)


# ------------------------------------------------------------
# 8. Mostrar resumo
# ------------------------------------------------------------

print("=" * 70)
print("CSV FINAL GERADO")
print("=" * 70)

print(f"Arquivo: {output_file.resolve()}")
print(f"Total de estudos únicos: {len(final_df)}")

print("\nSituação:")

display(
    final_df[
        "selection_status"
    ]
    .value_counts()
    .rename_axis("status")
    .reset_index(name="n")
)

print(
    "\nCandidatos para leitura integral:",
    (
        final_df["selection_status"]
        == "FULL_TEXT_CANDIDATE"
    ).sum()
)

print(
    "Revisão manual:",
    (
        final_df["selection_status"]
        == "MANUAL_REVIEW"
    ).sum()
)

print(
    "Abaixo do corte:",
    (
        final_df["selection_status"]
        == "BELOW_THRESHOLD"
    ).sum()
)

print(
    "Hard exclude:",
    (
        final_df["selection_status"]
        == "HARD_EXCLUDE"
    ).sum()
)

print(
    "Ainda pendentes:",
    (
        final_df["selection_status"]
        == "PENDING"
    ).sum()
)

print("\nPrimeiros registros:")

display(
    final_df[
        [
            "relevance_rank",
            "selection_status",
            "relevance_score",
            "confidence",
            "title",
            "sources",
            "study_type",
        ]
    ].head(20)
)
# Out:
# ======================================================================
# CSV FINAL GERADO
# ======================================================================
# Arquivo: C:\Users\Marcos Rocha\Downloads\prompt-injection-review\NEW\analysis_outputs\FINAL_screening_studies.csv
# Total de estudos únicos: 552
#
# Situação:
#                 status    n
# 0  FULL_TEXT_CANDIDATE  243
# 1              PENDING  190
# 2      BELOW_THRESHOLD   98
# 3        MANUAL_REVIEW   12
# 4         HARD_EXCLUDE    9
# Candidatos para leitura integral: 243
# Revisão manual: 12
# Abaixo do corte: 98
# Hard exclude: 9
# Ainda pendentes: 190
#
# Primeiros registros:
#    relevance_rank     selection_status  relevance_score  confidence  \
# 0               1  FULL_TEXT_CANDIDATE             0.99        0.99
# 1               1  FULL_TEXT_CANDIDATE             0.99        0.99
# 2               1  FULL_TEXT_CANDIDATE             0.99        0.99
# 3               1  FULL_TEXT_CANDIDATE             0.99        0.99
# 4               1  FULL_TEXT_CANDIDATE             0.99        0.99
# 5               1  FULL_TEXT_CANDIDATE             0.99        0.98
# 6               7  FULL_TEXT_CANDIDATE             0.96        0.99
# 7               7  FULL_TEXT_CANDIDATE             0.96        0.99
# 8               7  FULL_TEXT_CANDIDATE             0.96        0.99
# 9               7  FULL_TEXT_CANDIDATE             0.96        0.99
# 10              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 11              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 12              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 13              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 14              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 15              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 16              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 17              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 18              7  FULL_TEXT_CANDIDATE             0.96        0.99
# 19              7  FULL_TEXT_CANDIDATE             0.96        0.99
#
#                                                                                                                title  \
# 0   TrustTrace: Provenance-Aware Tracing of Indirect Prompt Injection Propagation in LLM-Assisted Learning Workflows
# 1                                               DarkCite: Unveiling Authority Bias as Implicit Rag Jailbreak Attacks
# 2                   Visual and Structural Prompt Injection in Medical Rag Systems: a Comparative Robustness Analysis
# 3                       Disrupting Large Language Models with Hidden Prompt Injection Attacks Embedded in HTML Pages
# 4                                                       Get My Drift? Catching LLM Task Drift with Activation Deltas
# 5                                Zero-Shot Tokenizer Transfer for Targeted Attacks on Retrieval-Augmented Generation
# 6                              Hold the Prompt (HODPOT): Defense Design for Securing the System Prompt of LLM Agents
# 7                               A Systematic Literature Review of Prompt Injection Attacks in LLM-Integrated Systems
# 8                               Automatically Generated Multi-Agent Framework for Jailbreaking Large Language Models
# 9                    Securing Vision-Language Models with a Robust Encoder Against Jailbreak and Adversarial Attacks
# 10                                      Distraction is All You Need for Multimodal Large Language Model Jailbreaking
# 11                      Immune: Improving Safety Against Jailbreaks in Multi-modal LLMs via Inference-Time Alignment
# 12                         Playing the Fool: Jailbreaking LLMs and Multimodal LLMs with Out-of-Distribution Strategy
# 13                           Audio Jailbreak Attacks: Exposing Vulnerabilities in SpeechGPT in a White-Box Framework
# 14        Image-based Prompt Injection: Hijacking Multimodal LLMs through Visually Embedded Adversarial Instructions
# 15                      ATTN-Defense: Attention-Guided Detection, Location and Removal for Indirect Prompt Injection
# 16                                                           PINA: Prompt Injection Attack Against Navigation Agents
# 17           IPI2: Mitigating Indirect Prompt Injections on Unmanned Aerial Vehicle Agents Using Physical Invariants
# 18                                CAS-J: Cross-Modal Attention Synergy for Jailbreaking Large Vision-Language Models
# 19                   Audio-Text Jailbreak Attack on Large Audio-Language Models: Towards Generality and Stealthiness
#
#    sources                  study_type
# 0     IEEE                   DETECTION
# 1     IEEE  PRIMARY_ATTACK_AND_DEFENSE
# 2     IEEE              PRIMARY_ATTACK
# 3     IEEE  PRIMARY_ATTACK_AND_DEFENSE
# 4     IEEE                   DETECTION
# 5     IEEE              PRIMARY_ATTACK
# 6     IEEE             PRIMARY_DEFENSE
# 7     IEEE                      REVIEW
# 8     IEEE                 RED_TEAMING
# 9     IEEE             PRIMARY_DEFENSE
# 10    IEEE              PRIMARY_ATTACK
# 11    IEEE             PRIMARY_DEFENSE
# 12    IEEE              PRIMARY_ATTACK
# 13    IEEE              PRIMARY_ATTACK
# 14    IEEE              PRIMARY_ATTACK
# 15    IEEE             PRIMARY_DEFENSE
# 16    IEEE              PRIMARY_ATTACK
# 17    IEEE             PRIMARY_DEFENSE
# 18    IEEE              PRIMARY_ATTACK
# 19    IEEE              PRIMARY_ATTACK
